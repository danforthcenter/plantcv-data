# %% [markdown]
# ### Tests new function and generate doc images
# Plot ecdf for object sizes

# %%
import os
import numpy as np
from plantcv import plantcv as pcv

# %%
# test image
name_gray = "01_hsv_saturation.jpg"#"input_gray_img.jpg"

img_gray, _,_ = pcv.readimage(name_gray)

# %%
# %matplotlib notebook
pcv.plot_image(img_gray)
img_gray.shape
# Out:
# <img src="data:image/png;base64,..." width="640">
# (400, 224)

# %%
# create binary mask by threshoding and save result
thres = 120
mask = np.where(img_gray > thres,255,0).astype(np.uint8)
pcv.print_image(mask, "mask.png")

# %%
# pcv.plot_image(mask)

# %% [markdown]
# #### ecdf for object sizes

# %%
# # ecdf for obj_size
# pcv.params.debug = None
ecdf_obj_size =  pcv.visualize.obj_size_ecdf(mask, title="Cumulative Distribution for Object Sizes")
pcv.print_image(ecdf_obj_size, "ecdf_obj_size.png")
# ecdf_obj_size
# Out:
# /opt/anaconda3/envs/plantcv/lib/python3.7/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
# /opt/anaconda3/envs/plantcv/lib/python3.7/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log10
# <img src="data:image/png;base64,..." width="640">
# /opt/anaconda3/envs/plantcv/lib/python3.7/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 1 rows containing missing values.
